# %%
import pandas as pd
import numpy as np
import openpyxl 
from datetime import date

# %%
data = pd.read_excel(r'raw-data.xlsx')

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Branch                           288 non-null    object
#  1   Month_Year                       288 non-null    datetime64[ns]
#  2   Total_Sales                      288 non-null    int64
#  3   Veg_Sales                        288 non-null    int64
#  4   NonVeg_Sales                     288 non-null    int64
#  5   South_Indian_Sales               288 non-null    int64
#  6   South_Indian_Quantity            288 non-null    int64
#  7   Chinese_Sales                    288 non-null    int64
#  8   Chinese_Quantity                 288 non-null    int64
#  9   North_Indian_Sales               288 non-null    int64
#  10  North_Indian_Quantity            288 non-null    int64
#  11  Arabian_Sales                    288 non-null    int64
# ...

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Zomato_Sales  Swiggy_Revenue_After_Commission  \
# ...

# %%
data['Year'] = data['Month_Year'].dt.year

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data['Month_Number'] = data['Month_Year'].dt.month

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data['Month_Name'] = data['Month_Year'].dt.month_name()

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data['Quarter'] = 'Q' + data['Month_Year'].dt.quarter.astype('str')

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Grocery_Expenses  Total_Salaries  Net_Profit  \
# ...

# %%
data['Swiggy_Sales']
# Out:
# 0      146367
# 1      220519
# 2      241833
# 3      281672
# 4      201389
#         ...
# 283    239670
# 284    214324
# 285    303346
# 286    284469
# 287    274867
# Name: Swiggy_Sales, Length: 288, dtype: int64

# %%
data['Zomato_Sales']
# Out:
# 0      150665
# 1      109993
# 2      230108
# 3      155420
# 4      153740
#         ...
# 283    169284
# 284    190603
# 285    128909
# 286    229372
# 287    163418
# Name: Zomato_Sales, Length: 288, dtype: int64

# %%
data['Online_Sales'] = data['Swiggy_Sales'] + data['Zomato_Sales'] / data['Total_Sales'] * 100

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Total_Salaries  Net_Profit  Total_Employees  \
# ...

# %%
data['Direct_Sales']
# Out:
# 0      432561
# 1      408195
# 2      670067
# 3      539598
# 4      549035
#         ...
# 283    554351
# 284    607180
# 285    587605
# 286    662007
# 287    625404
# Name: Direct_Sales, Length: 288, dtype: int64

# %%
data['Direct_Sales_Percent'] = data['Direct_Sales'] / data['Total_Sales'] *100

# %%
data['Direct_Sales_Percent']
# Out:
# 0      59.287987
# 1      55.258039
# 2      58.674458
# 3      55.247622
# 4      60.722944
#          ...
# 283    57.546779
# 284    59.991681
# 285    57.616241
# 286    56.300389
# 287    58.795757
# Name: Direct_Sales_Percent, Length: 288, dtype: float64

# %%
data['Total_Cuision_Sales'] = data['South_Indian_Sales'] + data['Chinese_Sales'] + data['North_Indian_Sales'] + data['Arabian_Sales']

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Total_Employees  Female_Employees  Male_Employees  \
# ...

# %%
data['Total_Quantity_Sold'] = data['North_Indian_Quantity'] + data['Chinese_Quantity'] + data['South_Indian_Quantity'] + data['Arabian_Quantity']

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Female_Employees  Male_Employees  Year  \
# ...

# %%
data['Average_Sales_Per_Item'] = data['Total_Cuision_Sales'] / data['Total_Quantity_Sold']

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Male_Employees  Year  Month_Number  Month_Name  \
# ...

# %%
data['Profit_Margin'] =data['Net_Profit'] / data['Total_Sales'] *100

# %%
data['Profit_Margin']
# Out:
# 0      64.999938
# 1      65.000061
# 2      64.999982
# 3      64.999949
# 4      65.000044
#          ...
# 283    64.999974
# 284    65.000044
# 285    65.000000
# 286    64.999983
# 287    65.000014
# Name: Profit_Margin, Length: 288, dtype: float64

# %%
data['Total_Expence_Ratio'] = data['Total_Expenses'] / data['Total_Sales'] *100

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Month_Number  Month_Name  Quarter   Online_Sales  \
# ...

# %%
data['Sales_Per_Employee'] = data['Total_Sales'] / data['Total_Employees']

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data['Male'] = data['Male_Employees'] / data['Total_Employees'] *100

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Quarter   Online_Sales  Direct_Sales_Percent  \
# ...

# %%
data['Female'] = data['Female_Employees'] / data['Total_Employees'] *100

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data['Swiggy_Commision'] = data['Swiggy_Sales'] - data['Swiggy_Revenue_After_Commission']

# %%
data['Zomato_Commision'] = data['Zomato_Sales'] - data['Zomato_Revenue_After_Commission']

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data['Total_Commision'] = data['Swiggy_Commision'] + data['Zomato_Commision']

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindigai 2025-06-01      1142008     463262        678746
# 3       Dindigai 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data.isnull().sum()
# Out:
# Branch                             0
# Month_Year                         0
# Total_Sales                        0
# Veg_Sales                          0
# NonVeg_Sales                       0
# South_Indian_Sales                 0
# South_Indian_Quantity              0
# Chinese_Sales                      0
# Chinese_Quantity                   0
# North_Indian_Sales                 0
# North_Indian_Quantity              0
# Arabian_Sales                      0
# Arabian_Quantity                   0
# Direct_Sales                       0
# Swiggy_Sales                       0
# Zomato_Sales                       0
# Swiggy_Revenue_After_Commission    0
# Zomato_Revenue_After_Commission    0
# Total_Expenses                     0
# Grocery_Expenses                   0
# Total_Salaries                     0
# Net_Profit                         0
# Total_Employees                    0
# Female_Employees                   0
# Male_Employees                     0
# ...

# %%
data.head()
# Out:
#         Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0      Chennai 2024-07-01       729593     285808        443785
# 1   Coimbatore 2024-07-01       738707     295848        442859
# 2     Dindigai 2025-06-01      1142008     463262        678746
# 3     Dindigai 2025-10-01       976690     413374        563316
# 4  Kanyakumari 2025-08-01       904164     353208        550956
#
#    South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  Chinese_Quantity  \
# 0              291837                   1167         182398               365
# 1              295483                   1182         184677               369
# 2              456803                   1827         285502               571
# 3              390676                   1563         244172               488
# 4              361666                   1447         226041               452
#
#    North_Indian_Sales  ...  Total_Quantity_Sold  Average_Sales_Per_Item  \
# ...

# %%
data['Branch'].unique()
# Out:
# array(['Chennai', 'Coimbatore', 'Dindigai', 'Kanyakumari', 'Madurai',
#        'Ooty', 'Salem', 'Tirunelveli', 'Kodaikanal', 'Thoothukudi',
#        'Tiruppur', 'Trichy'], dtype=object)

# %%
data['Branch'] = data['Branch'].replace("Dindigai","Dindugal")

# %%
data['Branch'].unique()
# Out:
# array(['Chennai', 'Coimbatore', 'Dindugal', 'Kanyakumari', 'Madurai',
#        'Ooty', 'Salem', 'Tirunelveli', 'Kodaikanal', 'Thoothukudi',
#        'Tiruppur', 'Trichy'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 42 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Branch                           288 non-null    object
#  1   Month_Year                       288 non-null    datetime64[ns]
#  2   Total_Sales                      288 non-null    int64
#  3   Veg_Sales                        288 non-null    int64
#  4   NonVeg_Sales                     288 non-null    int64
#  5   South_Indian_Sales               288 non-null    int64
#  6   South_Indian_Quantity            288 non-null    int64
#  7   Chinese_Sales                    288 non-null    int64
#  8   Chinese_Quantity                 288 non-null    int64
#  9   North_Indian_Sales               288 non-null    int64
#  10  North_Indian_Quantity            288 non-null    int64
#  11  Arabian_Sales                    288 non-null    int64
# ...

# %%
data
# Out:
#           Branch Month_Year  Total_Sales  Veg_Sales  NonVeg_Sales  \
# 0        Chennai 2024-07-01       729593     285808        443785
# 1     Coimbatore 2024-07-01       738707     295848        442859
# 2       Dindugal 2025-06-01      1142008     463262        678746
# 3       Dindugal 2025-10-01       976690     413374        563316
# 4    Kanyakumari 2025-08-01       904164     353208        550956
# ..           ...        ...          ...        ...           ...
# 283  Tirunelveli 2024-05-01       963305     424585        538720
# 284  Tirunelveli 2024-09-01      1012107     396269        615838
# 285     Tiruppur 2024-03-01      1019860     404051        615809
# 286     Tiruppur 2025-05-01      1175848     470687        705161
# 287       Trichy 2024-06-01      1063689     412747        650942
#
#      South_Indian_Sales  South_Indian_Quantity  Chinese_Sales  \
# 0                291837                   1167         182398
# ...

# %%
data.to_csv('featured-TAR-data.csv',index= False)
